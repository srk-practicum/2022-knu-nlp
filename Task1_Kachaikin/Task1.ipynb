# %% [markdown]
# # OPENING DATASET

# %%
import numpy as np
import pandas as pd
import nltk
import re

nltk.download('punkt') # I ACTUALLY DONT NOW WHAT IS THIS, BUT WITHOUT THAT IT DOESN'T WORK 
nltk.download('wordnet')
nltk.download('omw-1.4')

df = pd.read_csv('root2ai - Data.csv') # READING CSV FILE AND MAKE IT AS PANDAS DATAFRAME



u=list(df['Text']) #WE ARE TAKING ONLY TEXTS, BECAUSE WE DON'T WANT CLASSIFY 

df
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/markokachaikin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/markokachaikin/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/markokachaikin/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
#                                                     Text      Target
# 0      reserve bank forming expert committee based in...  Blockchain
# 1              director could play role financial system  Blockchain
# 2      preliminary discuss secure transaction study r...  Blockchain
# 3      security indeed prove essential transforming f...  Blockchain
# 4      bank settlement normally take three days based...  Blockchain
# ...                                                  ...         ...
# 22699  fourth study discusses blockchain technology e...    Reg Tech
# 22700  book finishes stating biggest issue emerging F...    Reg Tech
# 22701                                people culture cess    Reg Tech
# 22702  author challenges execu tive lead change stop ...    Reg Tech
# 22703  change data driven culture come bottom must start    Reg Tech
#
# [22704 rows x 2 columns]

# %% [markdown]
# ## CLEANING FROM STOPWORDS AND TOKENIZATION

# %%
nltk.download('stopwords') # THAT'S FOR IMPORTING TYPICAL ENGLISH STOPWORDS
from nltk.corpus import stopwords
R=''
for i in u:
    R+=str(i) #CREATE A STRING FROM LIST OF STRINGS
    
R = re.sub(r'[.,!?;:()/]{,1}',repl='',string= R) # CLEANING FROM PUNCTUATION
R = re.sub(r'\s{2,}',repl='',string= R) # CLEANING FROM EXTRA SPACES 


R=R.lower() #ALL WORDS TO LOWERCASE

text_tokens=nltk.word_tokenize(R) # TOKENIZATION 


stop_words=stopwords.words("english")

text_tokens_cleaned=[i for i in text_tokens if i not in stop_words] # TOKENS FROM TEXTS WITHOUT STOPWORDS

unique_text_tokens_cleaned = list(set(text_tokens_cleaned)) # UNIQUE TOKENS FROM TEXT WITHOUT STOPWORDS

R
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/markokachaikin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 'reserve bank forming expert committee based institute development research banking technology study approach distributed ledger technology help support shiftdirector could play role financial systempreliminary discuss secure transaction study research paymentsecurity indeed prove essential transforming financial system part effort move away heavy reliance cash basedbank settlement normally take three days based payment verification technology take less tier securityagarwal head bankseveral data security regulatory oversight would need widely financial systemrelevance transaction register available publicly sequential record serve effective tool transaction settlement among different payment chain chief risk officer global businesstechnology need transaction intermediary clearinghouse financial establishment thus quick secure inexpensiveseven bank morgan chase already support certain cross border fortunemeanwhile bank digital division harness technology according newsbank reportedly create position chief technology digital officerofficer report directly charge newly team technology digital group work solely improving bank digital reach technology said recent interview mintagarwal technology assist banking providing lower cost platform transaction securityexample bank create link point made received point confirmation another group providekhan deputy governor said recent presentation technology significant role play financial systemkhan lack card rather cashimplement customer liability framework ease cashwould define liability well banker debit credit encourage make card based khanbased open security alliance founder watch sure risk fraud substantially technology transparencyhowever question whether technology ready widespread adoption whether truly upsides cannot conventionalremains unclear financial industry would shift present regulatory regime quasi autonomous setup full advantageinclude strong alternative system current technology require design address fundamentalcross border legal lack consistent application needthird third operating infrastructure need tackle legal regulatoryneedcrime need incorporate address money illegal associated darksupport research design development biggest challenge adoption growth technology open security allianceread great consternation article answer evasion suggesting country storemove write would reduce evasion corruption streamline systemeven today world wrong headed policy incorrect understanding technology commonplace article impressive tour force egregiousfelt write response caution adoption shallow misleading seemingly comprehensive misunderstanding technology applicability economictask exposition technical seriousfirst fail consider problem scale data reside millionspermission less public ecosystem full size data participate platform computational maintain datafull network process single transaction since block time consuming math puzzle must agree block validnetwork whole every transaction consuming electricity approximately electricity consumption average household year according datasuggest able enjoy added convenience wait several process given make sweltering weather hotter still heat systemsecond present view sense consider permission less publicpublic permission less must entire transaction data available publicly node chance validaterealistic government expose collection data entire world classified military would cryptography would necessarily restrict possible secretcritical system would task even single failure would compromise extremely detailed economic information public private paying country irreversiblythus find surprising ignore plain fact governance viable permissioned privateadministration system would likely solution could participate collection government administration would distributed workpurely technical perspective probably viablereally open trustable solution confront much important issuepremise permission less public trust emerge system even individual sys ...

# %% [markdown]
# # STEMMING

# %%
from nltk.stem import PorterStemmer #Typical tool for stemming
porter=nltk.PorterStemmer() 

text_tokens_cleaned_stemized= [ porter.stem(i) for i in text_tokens_cleaned] 

unique_text_tokens_cleaned_stemized = [ porter.stem(i) for i in unique_text_tokens_cleaned ]

unique_text_tokens_cleaned_stemized
# Out:
# ['back',
#  'kunt',
#  'paymentinst',
#  'applicationoveral',
#  'sorypurpos',
#  'look',
#  'memoryregulatori',
#  'implementalso',
#  'coronainsiderretriev',
#  'cryptograph',
#  'creditnonfinanci',
#  'concernsmart',
#  'squash',
#  'developedcritiqu',
#  'throughput',
#  'channel',
#  'sectorasset',
#  'popul',
#  'schemesimilarli',
#  'control',
#  'host',
#  'frameworkconsid',
#  'chargingpow',
#  'streamlin',
#  'undertakingmost',
#  'point',
#  'easilyeffici',
#  'solar',
#  'attributescompli',
#  'economyinfrastructur',
#  'relinquishmentproperti',
#  'experienceaccord',
#  'freesimilar',
#  'financestart',
#  'datatheoret',
#  'financesom',
#  'rrp',
#  'goodspay',
#  'techcrunchtechcrunchtechnolog',
#  'nextadvisori',
#  'spot',
#  'permanentold',
#  'chilebank',
#  'paraguid',
#  'knowledgearticl',
#  'maintenancemoreov',
#  'innovationlik',
#  'followingexampl',
#  'numberfil',
#  'suffer',
#  'valuedbillionneon',
#  'computeronc',
#  'scrolljun',
#  'dataaccount',
#  'injuri',
#  'valu',
#  'regulationtherefor',
#  'startthey',
#  'analyticalmarket',
#  'socialberlinparabancaparaparadean',
#  'flexibl',
#  'surg',
#  'fivefrom',
#  'environmentfac',
#  'agarw',
#  'theconversatiaustralia',
#  'record',
#  'updat',
#  'analysistechnolog',
#  'processlack',
#  'falc',
#  'markethigh',
#  'footprint',
#  'insteadfair',
#  'manystrateg',
#  'loaninfoqarticl',
#  'maintenancekeep',
#  'techdiggway',
#  'centercont',
#  'taken',
#  'prematur',
#  'lifequest',
#  'plane',
#  'accel',
#  'genesisgrowth',
#  'basedgiven',
#  'performancelik',
#  'elsethos',
#  'definedfurth',
#  'illeg',
#  'head',
#  'financialmoreov',
#  'timesimultan',
#  'industryfirst',
#  'hardwaremisfit',
#  'needsbusinessr',
#  'errordifficult',
#  'toleranceamong',
#  'traction',
#  'libertiesharvard',
#  'ecosystemmust',
#  'associatedmobil',
#  'decadethi',
#  'dougla',
#  'relativest',
#  'handfulleav',
#  'marketmonitor',
#  'critic',
#  'success',
#  'acceptchina',
#  'providedhowev',
#  'rangingdirectli',
#  'equal',
#  'instinct',
#  'relat',
#  'welfarepost',
#  'contentiondesign',
#  'statist',
#  'flexiblefuzzycas',
#  'workflow',
#  'studi',
#  'easili',
#  'efficientfact',
#  'user',
#  'societyarxivarxivbibcod',
#  'preissupplementari',
#  'alonehelp',
#  'creditchinamajor',
#  'relycapit',
#  'headlin',
#  'securityl',
#  'findingmanag',
#  'excel',
#  'forecastingpersist',
#  'aggr',
#  'sectorsearch',
#  'textanalysi',
#  'mainaddit',
#  'linguist',
#  'infer',
#  'boomworld',
#  'automaticallytim',
#  'humanparticip',
#  'fullyfurthermor',
#  'inceptionretail',
#  'beast',
#  'bankwher',
#  'informationhigh',
#  'chargetransact',
#  'majorityupsid',
#  'associatedspokeanoth',
#  'incub',
#  'aggress',
#  'basedunderli',
#  'context',
#  'incub',
#  'comethrough',
#  'music',
#  'invit',
#  'casefrom',
#  'delin',
#  'technologystakehold',
#  'managementliteratur',
#  'strategyr',
#  'customerwhil',
#  'costreal',
#  'weigh',
#  'angelhowev',
#  'institutionsfinanci',
#  'techimport',
#  'accountingshift',
#  'collect',
#  'moneythu',
#  'economywel',
#  'creditthi',
#  'enabl',
#  'push',
#  'profbank',
#  'couldworld',
#  'marketunderstand',
#  'compar',
#  'rush',
#  'planconcept',
#  'inspir',
#  'fundsprovid',
#  'test',
#  'renaiss',
#  'visibilitynot',
#  'instancetranspar',
#  'conveniencetech',
#  'orchestrationinfrastructur',
#  'sectoralhighli',
#  'unlaw',
#  'needsregulatori',
#  'examplegood',
#  'algorithm',
#  'bankconsequ',
#  'cloudgoogcustom',
#  'organ',
#  'medicaldisast',
#  'mitig',
#  'relatedthes',
#  'burg',
#  'kotharisubramaniamanalysi',
#  'innovationalreadi',
#  'postedund',
#  'empir',
#  'initiativesestablish',
#  'previouslyeasili',
#  'transformovercom',
#  'couldanoth',
#  'understandingcaught',
#  'pour',
#  'unveil',
#  'pierr',
#  'worldinvest',
#  'sadhu',
#  'regimerec',
#  'networksshift',
#  'effortonli',
#  'researchfin',
#  'townsman',
#  'experiencebank',
#  'contemporari',
#  'routeminimum',
#  'internationalpubl',
#  'prudenti',
#  'junestori',
#  'reductionmoreov',
#  'modelsubstanti',
#  'tacklingapproach',
#  'marketrec',
#  'chemistri',
#  'recordasset',
#  'forumcollabor',
#  'regulatorydocu',
#  'startiniti',
#  'businessregardless',
#  'specimen',
#  'developmenthead',
#  'powerthat',
#  'availabledetermin',
#  'nova',
#  'researchaddit',
#  'moneybal',
#  'complianceexplain',
#  'mapreduc',
#  'eithermani',
#  'philosophi',
#  'consumersit',
#  'paymentwhat',
#  'reactprofit',
#  'corpo',
#  'fenc',
#  'accountbillion',
#  'advo',
#  'catastroph',
#  'holidayyour',
#  'rewardasset',
#  'focus',
#  'autumn',
#  'billionsitu',
#  'stolen',
#  'potentiallymor',
#  'specificcontext',
#  'wellfinanci',
#  'technologicalsimpl',
#  'leverag',
#  'sourcewould',
#  'paolo',
#  'financialsect',
#  'answerregul',
#  'multiplerec',
#  'transactionus',
#  'survivewhat',
#  'decemberandm',
#  'brandthough',
#  'industryadvisori',
#  'biolog',
#  'alternativene',
#  'wrongcadretruenew',
#  'desiredoften',
#  'partcircular',
#  'changeworld',
#  'ensur',
#  'peoplefair',
#  'hazard',
#  'strategymani',
#  'yearlyaddit',
#  'anonym',
#  'reportpermamccullagh',
#  'remov',
#  'globegood',
#  'equival',
#  'cnbc',
#  'unab',
#  'continueslikewis',
#  'manuallyaddit',
#  'partnershipsthi',
#  'advertisingconsult',
#  'regress',
#  'achievearchitectur',
#  'issueprevi',
#  'telltoward',
#  'legitim',
#  'collectionoveral',
#  'enact',
#  'deskdesk',
#  'transactionther',
#  'dissatisfact',
#  'choiceer',
#  'blogsegaran',
#  'welcomesapin',
#  'cultureconcret',
#  'applyord',
#  'horizonwhat',
#  'analysisspecif',
#  'welfarecredit',
#  'place',
#  'espionag',
#  'test',
#  'investmentfact',
#  'stiff',
#  'coveragedraft',
#  'availablecredit',
#  'malici',
#  'headsdelet',
#  'changehigh',
#  'terrifi',
#  'documentationquest',
#  'sectorfinanci',
#  'complianceprudenti',
#  'ideal',
#  'revolut',
#  'emergeunderstand',
#  'casefinanci',
#  'issueschalleng',
#  'internationallymust',
#  'knowledg',
#  'builtinnov',
#  'ethicssummar',
#  'finalreporthaip',
#  'physicsijrobpijrobpncbiarticlespmid',
#  'businesshowev',
#  'systemvalu',
#  'millionse',
#  'interestcommon',
#  'povertyfinanci',
#  'pointpotenti',
#  'demandresult',
#  'generalfetch',
#  'transformationcustom',
#  'predetermin',
#  'facilit',
#  'financialregulatori',
#  'capitalhowev',
#  'monthfinanci',
#  'companiesapril',
#  'replicationthi',
#  'realmlarg',
#  'lawfullythi',
#  'author',
#  'transactionamount',
#  'ruin',
#  'guidancewould',
#  'amountseg',
#  'environmentfirst',
#  'breadth',
#  'customerimport',
#  'supercomput',
#  'goodspow',
#  'emerg',
#  'highwaymor',
#  'ecosystemhop',
#  'unfoldingmajor',
#  'lend',
#  'elderli',
#  'presenttech',
#  'ultra',
#  'contextaft',
#  'settlementperson',
#  'index',
#  'riskspecif',
#  'fairli',
#  'appoint',
#  'recordalgorithm',
#  'smallpoorli',
#  'advisoryalso',
#  'futurerelev',
#  'solut',
#  'although',
#  'applicationthi',
#  'conclud',
#  'securitydistribut',
#  'usag',
#  'outsidestrongli',
#  'poster',
#  'brunt',
#  'assetstraditionalaltern',
#  'functionalityidea',
#  'morri',
#  'threerec',
#  'chapterfinanci',
#  'contentexampl',
#  'sandboxupon',
#  'conglomerateentir',
#  'digitalwhil',
#  'experienceregul',
#  'dataconomi',
#  'technologyforget',
#  'communityterm',
#  'curriculum',
#  'evidenceconvent',
#  'exceedingbillioncould',
#  'upgradegroup',
#  'conced',
#  'sourcediffer',
#  'rapid',
#  'affirm',
#  'deepen',
#  'rich',
#  'licensedlandscap',
#  'interconnectconveni',
#  'developmentaddit',
#  'noteedwardmurphi',
#  'businessopen',
#  'paye',
#  'warehouseitnewsnew',
#  'diverg',
#  'bornwhen',
#  'watersmal',
#  'previous',
#  'analyzedtoday',
#  'sexual',
#  'informationemerg',
#  'outcom',
#  'omittedbankofenglandpubl',
#  'demonstr',
#  'cornellnizan',
#  'boast',
#  'automotivecontext',
#  'ratio',
#  'transactionfollow',
#  'startcor',
#  'accesshigh',
#  'reportingsimilarli',
#  'ockbust',
#  'userhistor',
#  'ivando',
#  'informationplatform',
#  'distanc',
#  'informationglob',
#  'affordablestructur',
#  'puzzleinvolv',
#  'enrich',
#  'activitiesfeder',
#  'eas',
#  'collaboratestart',
#  'inhibit',
#  'relat',
#  'rolethi',
#  'paperrec',
#  'marketther',
#  'pleaseinfoqlatest',
#  'potentialg',
#  'stern',
#  'marketnevertheless',
#  'cleans',
#  'accountdriven',
#  'unquestionableconjunct',
#  'back',
#  'landscapeher',
#  'mode',
#  'datasampl',
#  'creditsom',
#  'smallmoney',
#  'carenecessari',
#  'innovationmoreov',
#  'overviewintern',
#  'initi',
#  'performancesom',
#  'futur',
#  'numberwest',
#  'confid',
#  'accessopen',
#  'trustther',
#  'experiencebecaus',
#  'touch',
#  'competitionthird',
#  'relyp',
#  'think',
#  'gener',
#  'piec',
#  'largest',
#  'array',
#  'councilcard',
#  'supportdesign',
#  'devot',
#  'fintechchannel',
#  'presentkind',
#  'kappacontactthi',
#  'januarywhat',
#  'equivalentstock',
#  'stolensinc',
#  'industrysimilar',
#  'comebecaus',
#  'grade',
#  'outstandinghom',
#  'collectedfurth',
#  'chequ',
#  'quak',
#  'traditionalonlyrelationship',
#  'stein',
#  'banker',
#  'futurepres',
#  'regtechthird',
#  'scotch',
#  'dealmemb',
#  'crimeworld',
#  'economydigit',
#  'organizationwil',
#  'businesssinc',
#  'sweet',
#  'carriedhowev',
#  'vulnerabilitydata',
#  'basepubl',
#  'environmentord',
#  'financialcompli',
#  'agreement',
#  'portfoliocr',
#  'orderexcept',
#  'microrec',
#  'industryexamin',
#  'stubborn',
#  'respectivepriv',
#  'innovationher',
#  'respectivelydur',
#  'theoryadopt',
#  'like',
#  'startmuch',
#  'fie',
#  'fidel',
#  'contradictori',
#  'attribut',
#  'potentialcomputerworldmarchretriev',
#  'settingresult',
#  'startthi',
#  'formcampaign',
#  'organ',
#  'long',
#  'atop',
#  'pointinvoic',
#  'wholeheartedli',
#  'partnershiptradit',
#  'paymentbecaus',
#  'shane',
#  'clan',
#  'remark',
#  'toll',
#  'currencydigit',
#  'faceexplor',
#  'knowingli',
#  'pasttak',
#  'junecomprehens',
#  'insurmount',
#  'stress',
#  'ultim',
#  'diversif',
#  'futuremorgan',
#  'springboard',
#  'forwardncbiarticlesscientif',
#  'leadershipn',
#  'locallyonc',
#  'watch',
#  'limitdigit',
#  'monitorchit',
#  'partnershipmain',
#  'hereinaft',
#  'googletim',
#  'column',
#  'startmost',
#  'tinker',
#  'verificationfact',
#  'consumerhigh',
#  'objectconsensu',
#  'protectionquick',
#  'sciencethi',
#  'market',
#  'rupeetechnolog',
#  'bluntli',
#  'kenya',
#  'startcollabor',
#  'team',
#  'product',
#  'uneconom',
#  'swath',
#  'millionform',
#  'result',
#  'stocksever',
#  'sectoraddit',
#  'directlypartn',
#  'supervisorystart',
#  'memberful',
#  'rateinflationdecimalratecroregoldbarrelforeign',
#  'enabl',
#  'seriesdata',
#  'worryingplu',
#  'dormant',
#  'frameworksect',
#  'improp',
#  'tweet',
#  'inadequateregtech',
#  'supportlik',
#  'insightsabstract',
#  'industryshowcas',
#  'advertisingus',
#  'moneytechnolog',
#  'pyramidunbank',
#  'regulationrestrict',
#  'support',
#  'anotherclear',
#  'sandersimport',
#  'advisor',
#  'valid',
#  'innov',
#  'howeverremot',
#  'globallyalso',
#  'bankingrapid',
#  'malik',
#  'sectordefault',
#  'puzzledwhat',
#  'congruent',
#  'dawn',
#  'sciencemarchprintjourn',
#  'judg',
#  'theart',
#  'timeparticular',
#  'thin',
#  'existsrec',
#  'sometimesther',
#  'areahigh',
#  'ecosystemcr',
#  'schemeprimari',
#  'accuraterefin',
#  'processalso',
#  'strategi',
#  'impervi',
#  'kate',
#  'cabinetdata',
#  'consumpt',
#  'stagger',
#  'algorithm',
#  'customereasi',
#  'waterfal',
#  'incompat',
#  'staff',
#  'nonperson',
#  'attract',
#  'regulatoryappl',
#  'promot',
#  'restfutur',
#  'differentemerg',
#  'doubledaddit',
#  'marchthen',
#  'creditne',
#  'financialwel',
#  'illiteracylarg',
#  'solutionresult',
#  'complianceorder',
#  'develop',
#  'unawar',
#  'lostfinanci',
#  'economicfinanci',
#  'use',
#  'hygieneopen',
#  'forc',
#  'conduc',
#  'cloud',
#  'angela',
#  'activitysuch',
#  'personpay',
#  'investmentadvisori',
#  'workvari',
#  'technologyretail',
#  'collaborationsever',
#  'grant',
#  'advoc',
#  'featureanoth',
#  'domainverif',
#  'civil',
#  'previousaddit',
#  'eventuallytim',
#  'settingdefault',
#  'includ',
#  'asymmetri',
#  'toolswhen',
#  'delortpageoecdretriev',
#  'unstar',
#  'competitioncountless',
#  'karma',
#  'bankthat',
#  'industrybetter',
#  'quadratictradit',
#  'buildluckili',
#  'globallook',
#  'securityempow',
#  'footprintsecond',
#  'lenient',
#  'resultspresidenti',
#  'informationleg',
#  'zetzschethi',
#  'offerunfinish',
#  'educationunlik',
#  'market',
#  'unit',
#  'friendexperi',
#  'rel',
#  'exist',
#  'spatial',
#  'investmentunlik',
#  'phone',
#  'significantpetrol',
#  'india',
#  'exchang',
#  'coveredchina',
#  'notari',
#  'traditionallarg',
#  'bling',
#  'traditionalawar',
#  'recognitionpatcogpatcogpllana',
#  'harish',
#  'chair',
#  'datathey',
#  'trade',
#  'monitor',
#  'await',
#  'suitemultipl',
#  'revolutionnevertheless',
#  'changene',
#  'sprung',
#  'exactli',
#  'systemstori',
#  'mistakewhen',
#  'sewag',
#  'intelligencefor',
#  'solutionbas',
#  'phaseindustri',
#  'successor',
#  'discriminationhuman',
#  'branchaccount',
#  'call',
#  'extern',
#  'withinthi',
#  'conceptu',
#  'immediatelyport',
#  'marketpap',
#  'initiallyespeci',
#  'traditionalimport',
#  'distributedher',
#  'compris',
#  'economicdigit',
#  'reviewus',
#  'baseddemonstr',
#  'engagementdecid',
#  'growthunlik',
#  'globalvalu',
#  'productionoveral',
#  'futuretradit',
#  'datatarget',
#  'platformproven',
#  'mmd',
#  'discrimin',
#  'power',
#  'portfolioconcurr',
#  'principleregist',
#  'processencourag',
#  'discret',
#  'maggiemcgrath',
#  'china',
#  'result',
#  'approv',
#  'prepar',
#  'entirelyris',
#  'connectedexperi',
#  'analyzebusi',
#  'capacityinst',
#  'restrain',
#  'risingdailyhowev',
#  'analyticsfjmasemanticscholarcorpusidjonathan',
#  'criteriastatist',
#  'lake',
#  'grant',
#  'aprilwebst',
#  'virtualeach',
#  'blockcreat',
#  'iri',
#  'transform',
#  'staffteam',
#  'movi',
#  'prospect',
#  'wouldcompani',
#  'casual',
#  'warehous',
#  'recessionord',
#  'affairsdocumento',
#  'distributionthes',
#  'locationcurr',
#  'countrywhil',
#  'latencywors',
#  'summeraft',
#  'timeseri',
#  'stabl',
#  'abstract',
#  'ordervalu',
#  'volatil',
#  'dataent',
#  'bankpeer',
#  'thisensur',
#  'assum',
#  'remembr',
#  'tionfintech',
#  'lendplatform',
#  'desir',
#  'neutralitythi',
#  'kong',
#  'justifi',
#  'respect',
#  'technologybest',
#  'protectionreform',
#  'devastatingcours',
#  'deploy',
#  'traditionalpesa',
#  'startfocu',
#  'riskslikewis',
#  'savvyprovid',
#  'bankelast',
#  'profileanoth',
#  'apparentgo',
#  'focu',
#  'comparisonoften',
#  'fosteringalso',
#  'basedequ',
#  'reporthigh',
#  'tradingspecif',
#  'associatedcit',
#  'insuffici',
#  'referencemost',
#  'greenplum',
#  'dynamicallyhandl',
#  'bankingmight',
#  'accreditedchoos',
#  'stude',
#  'timeformula',
#  'stand',
#  'includealthough',
#  'hors',
#  'controlthi',
#  'wari',
#  'securefreestudi',
#  'banklat',
#  'pacif',
#  'usedmov',
#  'applicationcomplex',
#  'scanti',
#  'staggeringelectr',
#  'root',
#  'acceptancetechnolog',
#  'reversedcommiss',
#  'tomorrow',
#  'cardhand',
#  'scaleintent',
#  'violat',
#  'addresspriv',
#  'score',
#  'needfuturist',
#  'companysuccess',
#  'analyzerel',
#  'protectionthu',
#  'qualitymus',
#  'togetherparticular',
#  'ship',
#  'mind',
#  'observ',
#  'standardsuspect',
#  'steadili',
#  'ought',
#  'detailtrust',
#  'straightwhat',
#  'unidentifiedconnect',
#  'fit',
#  'digitalbeliev',
#  'deliveryfinanci',
#  'academicsooluwada',
#  'audit',
#  'focusparticular',
#  'appssinc',
#  'shoot',
#  'culturetremend',
#  'wellexecut',
#  'artifici',
#  'cooper',
#  'tradingcontact',
#  'marketmobil',
#  'construct',
#  'drastic',
#  'declar',
#  'ineffect',
#  'octobersoftwar',
#  'countryord',
#  'ethnic',
#  'identicalsystemat',
#  'intak',
#  'richard',
#  'embodi',
#  'adoptionmeta',
#  'datamillionleft',
#  'corporationsless',
#  'tradepay',
#  'loyaltyworld',
#  'waysactu',
#  'consumerleg',
#  'izat',
#  'realitymean',
#  'dupont',
#  'manymuch',
#  'rock',
#  'kindletim',
#  'complexthi',
#  'secretcrit',
#  'seriesmodel',
#  'transitioncr',
#  'realityorigin',
#  'conscienc',
#  'electroniceveri',
#  'infancysever',
#  'comparesinc',
#  'inclusionamong',
#  'tackl',
#  'scorefigur',
#  'inaugur',
#  'involv',
#  'additionalher',
#  'surveyrath',
#  'financialchief',
#  'assistanceinclud',
#  'ratenot',
#  'languageonc',
#  'latterdistinct',
#  'digitalorgan',
#  'disruptor',
#  'scrutinyotherwis',
#  'midst',
#  'learn',
#  'organizationfraud',
#  'basismin',
#  'bankablelat',
#  'amplab',
#  'affiliationthough',
#  'lighthous',
#  'consideredbenefit',
#  'proposaldelet',
#  'motiv',
#  'entireti',
#  'compuls',
#  'threat',
#  'map',
#  'expensivethes',
#  'progress',
#  'tensor',
#  'lessgiv',
#  'riskevalu',
#  'broadridg',
#  'depthdata',
#  'cumbent',
#  'traditionalcollect',
#  'regress',
#  'receiv',
#  'techbank',
#  'healthcar',
#  'handl',
#  'ledgerthough',
#  'deviat',
#  'demonet',
#  'properlymoreov',
#  'adoptionalso',
#  'constraint',
#  'digitallyfactor',
#  'marketexplor',
#  'sear',
#  'keepinghand',
#  'millionecosystem',
#  'governmentcommerc',
#  'showrememb',
#  'afford',
#  'openbecom',
#  'millionmillion',
#  'ieeesign',
#  'emergenceshortli',
#  'allegi',
#  'annualvulner',
#  ...]

# %% [markdown]
# # LEMMATIZATION

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = nltk.WordNetLemmatizer()

text_tokens_cleaned_lemmatized = [ lemmatizer.lemmatize(t) for t in text_tokens_cleaned]

unique_text_tokens_cleaned_lemmatized = [ lemmatizer.lemmatize(t) for t in unique_text_tokens_cleaned]

text_tokens_cleaned_lemmatized
# Out:
# ['reserve',
#  'bank',
#  'forming',
#  'expert',
#  'committee',
#  'based',
#  'institute',
#  'development',
#  'research',
#  'banking',
#  'technology',
#  'study',
#  'approach',
#  'distributed',
#  'ledger',
#  'technology',
#  'help',
#  'support',
#  'shiftdirector',
#  'could',
#  'play',
#  'role',
#  'financial',
#  'systempreliminary',
#  'discus',
#  'secure',
#  'transaction',
#  'study',
#  'research',
#  'paymentsecurity',
#  'indeed',
#  'prove',
#  'essential',
#  'transforming',
#  'financial',
#  'system',
#  'part',
#  'effort',
#  'move',
#  'away',
#  'heavy',
#  'reliance',
#  'cash',
#  'basedbank',
#  'settlement',
#  'normally',
#  'take',
#  'three',
#  'day',
#  'based',
#  'payment',
#  'verification',
#  'technology',
#  'take',
#  'le',
#  'tier',
#  'securityagarwal',
#  'head',
#  'bankseveral',
#  'data',
#  'security',
#  'regulatory',
#  'oversight',
#  'would',
#  'need',
#  'widely',
#  'financial',
#  'systemrelevance',
#  'transaction',
#  'register',
#  'available',
#  'publicly',
#  'sequential',
#  'record',
#  'serve',
#  'effective',
#  'tool',
#  'transaction',
#  'settlement',
#  'among',
#  'different',
#  'payment',
#  'chain',
#  'chief',
#  'risk',
#  'officer',
#  'global',
#  'businesstechnology',
#  'need',
#  'transaction',
#  'intermediary',
#  'clearinghouse',
#  'financial',
#  'establishment',
#  'thus',
#  'quick',
#  'secure',
#  'inexpensiveseven',
#  'bank',
#  'morgan',
#  'chase',
#  'already',
#  'support',
#  'certain',
#  'cross',
#  'border',
#  'fortunemeanwhile',
#  'bank',
#  'digital',
#  'division',
#  'harness',
#  'technology',
#  'according',
#  'newsbank',
#  'reportedly',
#  'create',
#  'position',
#  'chief',
#  'technology',
#  'digital',
#  'officerofficer',
#  'report',
#  'directly',
#  'charge',
#  'newly',
#  'team',
#  'technology',
#  'digital',
#  'group',
#  'work',
#  'solely',
#  'improving',
#  'bank',
#  'digital',
#  'reach',
#  'technology',
#  'said',
#  'recent',
#  'interview',
#  'mintagarwal',
#  'technology',
#  'assist',
#  'banking',
#  'providing',
#  'lower',
#  'cost',
#  'platform',
#  'transaction',
#  'securityexample',
#  'bank',
#  'create',
#  'link',
#  'point',
#  'made',
#  'received',
#  'point',
#  'confirmation',
#  'another',
#  'group',
#  'providekhan',
#  'deputy',
#  'governor',
#  'said',
#  'recent',
#  'presentation',
#  'technology',
#  'significant',
#  'role',
#  'play',
#  'financial',
#  'systemkhan',
#  'lack',
#  'card',
#  'rather',
#  'cashimplement',
#  'customer',
#  'liability',
#  'framework',
#  'ease',
#  'cashwould',
#  'define',
#  'liability',
#  'well',
#  'banker',
#  'debit',
#  'credit',
#  'encourage',
#  'make',
#  'card',
#  'based',
#  'khanbased',
#  'open',
#  'security',
#  'alliance',
#  'founder',
#  'watch',
#  'sure',
#  'risk',
#  'fraud',
#  'substantially',
#  'technology',
#  'transparencyhowever',
#  'question',
#  'whether',
#  'technology',
#  'ready',
#  'widespread',
#  'adoption',
#  'whether',
#  'truly',
#  'upside',
#  'conventionalremains',
#  'unclear',
#  'financial',
#  'industry',
#  'would',
#  'shift',
#  'present',
#  'regulatory',
#  'regime',
#  'quasi',
#  'autonomous',
#  'setup',
#  'full',
#  'advantageinclude',
#  'strong',
#  'alternative',
#  'system',
#  'current',
#  'technology',
#  'require',
#  'design',
#  'address',
#  'fundamentalcross',
#  'border',
#  'legal',
#  'lack',
#  'consistent',
#  'application',
#  'needthird',
#  'third',
#  'operating',
#  'infrastructure',
#  'need',
#  'tackle',
#  'legal',
#  'regulatoryneedcrime',
#  'need',
#  'incorporate',
#  'address',
#  'money',
#  'illegal',
#  'associated',
#  'darksupport',
#  'research',
#  'design',
#  'development',
#  'biggest',
#  'challenge',
#  'adoption',
#  'growth',
#  'technology',
#  'open',
#  'security',
#  'allianceread',
#  'great',
#  'consternation',
#  'article',
#  'answer',
#  'evasion',
#  'suggesting',
#  'country',
#  'storemove',
#  'write',
#  'would',
#  'reduce',
#  'evasion',
#  'corruption',
#  'streamline',
#  'systemeven',
#  'today',
#  'world',
#  'wrong',
#  'headed',
#  'policy',
#  'incorrect',
#  'understanding',
#  'technology',
#  'commonplace',
#  'article',
#  'impressive',
#  'tour',
#  'force',
#  'egregiousfelt',
#  'write',
#  'response',
#  'caution',
#  'adoption',
#  'shallow',
#  'misleading',
#  'seemingly',
#  'comprehensive',
#  'misunderstanding',
#  'technology',
#  'applicability',
#  'economictask',
#  'exposition',
#  'technical',
#  'seriousfirst',
#  'fail',
#  'consider',
#  'problem',
#  'scale',
#  'data',
#  'reside',
#  'millionspermission',
#  'le',
#  'public',
#  'ecosystem',
#  'full',
#  'size',
#  'data',
#  'participate',
#  'platform',
#  'computational',
#  'maintain',
#  'datafull',
#  'network',
#  'process',
#  'single',
#  'transaction',
#  'since',
#  'block',
#  'time',
#  'consuming',
#  'math',
#  'puzzle',
#  'must',
#  'agree',
#  'block',
#  'validnetwork',
#  'whole',
#  'every',
#  'transaction',
#  'consuming',
#  'electricity',
#  'approximately',
#  'electricity',
#  'consumption',
#  'average',
#  'household',
#  'year',
#  'according',
#  'datasuggest',
#  'able',
#  'enjoy',
#  'added',
#  'convenience',
#  'wait',
#  'several',
#  'process',
#  'given',
#  'make',
#  'sweltering',
#  'weather',
#  'hotter',
#  'still',
#  'heat',
#  'systemsecond',
#  'present',
#  'view',
#  'sense',
#  'consider',
#  'permission',
#  'le',
#  'publicpublic',
#  'permission',
#  'le',
#  'must',
#  'entire',
#  'transaction',
#  'data',
#  'available',
#  'publicly',
#  'node',
#  'chance',
#  'validaterealistic',
#  'government',
#  'expose',
#  'collection',
#  'data',
#  'entire',
#  'world',
#  'classified',
#  'military',
#  'would',
#  'cryptography',
#  'would',
#  'necessarily',
#  'restrict',
#  'possible',
#  'secretcritical',
#  'system',
#  'would',
#  'task',
#  'even',
#  'single',
#  'failure',
#  'would',
#  'compromise',
#  'extremely',
#  'detailed',
#  'economic',
#  'information',
#  'public',
#  'private',
#  'paying',
#  'country',
#  'irreversiblythus',
#  'find',
#  'surprising',
#  'ignore',
#  'plain',
#  'fact',
#  'governance',
#  'viable',
#  'permissioned',
#  'privateadministration',
#  'system',
#  'would',
#  'likely',
#  'solution',
#  'could',
#  'participate',
#  'collection',
#  'government',
#  'administration',
#  'would',
#  'distributed',
#  'workpurely',
#  'technical',
#  'perspective',
#  'probably',
#  'viablereally',
#  'open',
#  'trustable',
#  'solution',
#  'confront',
#  'much',
#  'important',
#  'issuepremise',
#  'permission',
#  'le',
#  'public',
#  'trust',
#  'emerge',
#  'system',
#  'even',
#  'individual',
#  'system',
#  'untrustedsetting',
#  'permissioned',
#  'private',
#  'form',
#  'outlined',
#  'presuppose',
#  'trust',
#  'limited',
#  'number',
#  'opaque',
#  'within',
#  'government',
#  'controlmust',
#  'presuppose',
#  'trust',
#  'might',
#  'well',
#  'trust',
#  'central',
#  'entity',
#  'conglomerateentirely',
#  'within',
#  'state',
#  'control',
#  'whole',
#  'point',
#  'generate',
#  'trust',
#  'even',
#  'state',
#  'untrustworthythus',
#  'private',
#  'permissioned',
#  'distributed',
#  'technological',
#  'sense',
#  'agency',
#  'human',
#  'institutionalcontrol',
#  'therefore',
#  'becomes',
#  'distributed',
#  'application',
#  'certain',
#  'desirable',
#  'redundant',
#  'storage',
#  'single',
#  'point',
#  'failure',
#  'corruption',
#  'certain',
#  'undesirable',
#  'high',
#  'response',
#  'time',
#  'energy',
#  'consumptioninvolved',
#  'authority',
#  'single',
#  'power',
#  'would',
#  'case',
#  'system',
#  'would',
#  'revenue',
#  'service',
#  'aegis',
#  'well',
#  'collude',
#  'manipulate',
#  'easilyalso',
#  'note',
#  'claim',
#  'without',
#  'evidence',
#  'insurance',
#  'settle',
#  'payment',
#  'baseddeeply',
#  'involved',
#  'technology',
#  'scape',
#  'past',
#  'three',
#  'safely',
#  'truecompany',
#  'article',
#  'even',
#  'claim',
#  'building',
#  'product',
#  'insurance',
#  'settlementpromise',
#  'reality',
#  'quite',
#  'characteristic',
#  'basedunderlying',
#  'technology',
#  'behind',
#  'extremely',
#  'interesting',
#  'inspiring',
#  'demonstrate',
#  'beyond',
#  'escrowpermissioned',
#  'also',
#  'useful',
#  'multiple',
#  'trust',
#  'need',
#  'business',
#  'contract',
#  'compliance',
#  'service',
#  'level',
#  'agreement',
#  'complianceorderer',
#  'thus',
#  'creation',
#  'trust',
#  'untrustedimportant',
#  'control',
#  'single',
#  'entity',
#  'apparent',
#  'trust',
#  'trustsystem',
#  'need',
#  'understanding',
#  'economic',
#  'problem',
#  'claim',
#  'also',
#  'sparse',
#  'primarily',
#  'corruption',
#  'prominently',
#  'fictional',
#  'series',
#  'white',
#  'tigergenre',
#  'evasion',
#  'problem',
#  'based',
#  'solution',
#  'could',
#  'possibly',
#  'solve',
#  'seen',
#  'film',
#  'people',
#  'running',
#  'illegal',
#  'mining',
#  'business',
#  'unspecifiedtaxation',
#  'imply',
#  'people',
#  'handling',
#  'surreptitiously',
#  'alterbased',
#  'system',
#  'someone',
#  'would',
#  'bribe',
#  'least',
#  'halfmuch',
#  'incontrovertibly',
#  'truelittle',
#  'evidence',
#  'alone',
#  'large',
#  'enough',
#  'scale',
#  'warrant',
#  'concernfirst',
#  'place',
#  'ratio',
#  'quite',
#  'comparable',
#  'level',
#  'economic',
#  'developmentsecond',
#  'extent',
#  'anomalously',
#  'concern',
#  'concern',
#  'heavily',
#  'respect',
#  'direct',
#  'like',
#  'income',
#  'indirect',
#  'likeincome',
#  'collection',
#  'turn',
#  'arise',
#  'nearly',
#  'half',
#  'population',
#  'agricultural',
#  'income',
#  'assessed',
#  'agricultural',
#  'income',
#  'informal',
#  'scale',
#  'whose',
#  'incentive',
#  'declare',
#  'level',
#  'income',
#  'country',
#  'generalfetched',
#  'think',
#  'distributed',
#  'ledger',
#  'store',
#  'instead',
#  'simple',
#  'move',
#  'needle',
#  'respect',
#  'collection',
#  'believe',
#  'shifting',
#  'gearless',
#  'bicycle',
#  'allow',
#  'cycle',
#  'moongoes',
#  'generalist',
#  'eventually',
#  'come',
#  'know',
#  'nothing',
#  'everything',
#  'specialist',
#  'eventually',
#  'come',
#  'know',
#  'everything',
#  'nothingspecialist',
#  'seek',
#  'advise',
#  'generalist',
#  'improve',
#  'public',
#  'welfare',
#  'delivery',
#  'must',
#  'subjected',
#  'rigorous',
#  'scrutinyotherwise',
#  'promising',
#  'delivery',
#  'progress',
#  'seek',
#  'stimulatefirst',
#  'technology',
#  'possiblevariety',
#  'advocate',
#  'deal',
#  'evasionenergy',
#  'efficient',
#  'example',
#  'consensus',
#  'proof',
#  'stake',
#  'proof',
#  'authority',
#  'require',
#  'intensiveoffer',
#  'repudiable',
#  'identifiable',
#  'coupled',
#  'smart',
#  'used',
#  'create',
#  'deterministic',
#  'logic',
#  'hackeddesign',
#  'system',
#  'complex',
#  'course',
#  'many',
#  'would',
#  'authentication',
#  'privacy',
#  'importantly',
#  'integration',
#  'enterprisepossible',
#  'need',
#  'drastically',
#  'impact',
#  'carbon',
#  'footprintsecond',
#  'leave',
#  'public',
#  'decide',
#  'whether',
#  'related',
#  'evasion',
#  'corruption',
#  'occurregularly',
#  'field',
#  'research',
#  'evasion',
#  'numerous',
#  'good',
#  'smallwonder',
#  'whether',
#  'reaching',
#  'liningthough',
#  'reliable',
#  'data',
#  'hard',
#  'find',
#  'illegality',
#  'drug',
#  'arm',
#  'illegal',
#  'immigrationevasionassuming',
#  'moment',
#  'however',
#  'little',
#  'evasion',
#  'combined',
#  'still',
#  'yield',
#  'efficiency',
#  'transparency',
#  'gain',
#  'collectionbeyond',
#  'system',
#  'capable',
#  'providing',
#  'evidence',
#  'little',
#  'evasion',
#  'corruptionfinally',
#  'reason',
#  'concerned',
#  'system',
#  'fully',
#  'statestate',
#  'capacity',
#  'state',
#  'tyrannically',
#  'peopleaffirm',
#  'conviction',
#  'would',
#  'beneficial',
#  'multiple',
#  'private',
#  'stand',
#  'state',
#  'society',
#  'issue',
#  'collectionpower',
#  'manner',
#  'especially',
#  'combined',
#  'would',
#  'help',
#  'ensure',
#  'efficient',
#  'collection',
#  'lead',
#  'state',
#  'capable',
#  'populationregulation',
#  'official',
#  'digital',
#  'currency',
#  'bill',
#  'first',
#  'clear',
#  'intent',
#  'launch',
#  'digital',
#  'rupeereserve',
#  'bank',
#  'join',
#  'growing',
#  'list',
#  'central',
#  'across',
#  'world',
#  'seriously',
#  'exploring',
#  'introduction',
#  'central',
#  'bank',
#  'digital',
#  'currencybank',
#  'international',
#  'central',
#  'bank',
#  'digital',
#  'money',
#  'national',
#  'unit',
#  'account',
#  'liability',
#  'central',
#  'bankcentral',
#  'view',
#  'sovereign',
#  'backed',
#  'issuance',
#  'monetary',
#  'supply',
#  'measure',
#  'economy',
#  'currency',
#  'circulationtext',
#  'bill',
#  'public',
#  'highly',
#  'likely',
#  'type',
#  'lookingsurvey',
#  'bank',
#  'international',
#  'settlement',
#  'found',
#  'retail',
#  'financial',
#  'inclusion',
#  'efficiencydiverse',
#  'country',
#  'digital',
#  'literacydigital',
#  'rupee',
#  'gain',
#  'acceptance',
#  'would',
#  'need',
#  'designed',
#  'manner',
#  'easily',
#  'accessible',
#  'usable',
#  'much',
#  'like',
#  'physical',
#  'cashdesign',
#  'would',
#  'consider',
#  'various',
#  'digital',
#  'literacy',
#  'acrossbackdrop',
#  'design',
#  'would',
#  'need',
#  'consider',
#  'following',
#  'ensure',
#  'widespread',
#  'acceptability',
#  'usage',
#  'ease',
#  'crucial',
#  'wide',
#  'spread',
#  'adoptionwould',
#  'necessary',
#  'digital',
#  'rupee',
#  'functionalityseveral',
#  'exploring',
#  'possibility',
#  'digital',
#  'currencyprimary',
#  'medium',
#  'smart',
#  'wearablehowever',
#  'country',
#  'like',
#  'feature',
#  'cost',
#  'accessible',
#  'common',
#  'also',
#  'consideredbased',
#  'feature',
#  'phone',
#  'wearable',
#  'reach',
#  'last',
#  'mile',
#  'important',
#  'consider',
#  'people',
#  'digital',
#  'rupeeanything',
#  'digital',
#  'need',
#  'digital',
#  'mediumdrive',
#  'phonealthough',
#  'currently',
#  'show',
#  'considerable',
#  'promise',
#  'reality',
#  'penetration',
#  'stood',
#  'le',
#  'centsmart',
#  'card',
#  'based',
#  'feature',
#  'smart',
#  'wearable',
#  'cost',
#  'even',
#  'supplementalmust',
#  'also',
#  'look',
#  'accessibility',
#  'storage',
#  'digital',
#  'rupee',
#  'phone',
#  'form',
#  'factor',
#  'devicebrowser',
#  'based',
#  'well',
#  'someone',
#  'device',
#  'distributed',
#  'ledger',
#  'based',
#  'currency',
#  'another',
#  ...]

# %% [markdown]
# # WORDCLOUD

# %%
from wordcloud import WordCloud

import matplotlib.pyplot as plt

v = list(df['Target'])
if len(u)==len(v):
    A=[[u[i],v[i]] for i in range(len(u))]
blockchain_texts=''
for i in A:
    if i[1]== 'Blockchain' :
        blockchain_texts+=i[0]

blockchain_texts = re.sub(r'[.,!?;:()/]{,1}',repl='',string= blockchain_texts) # CLEANING FROM PUNCTUATION
blockchain_texts = re.sub(r'\s{2,}',repl='',string= blockchain_texts) # CLEANING FROM EXTRA SPACES 

blockchain_texts.lower()



bigrm = list(nltk.bigrams(blockchain_texts.split()))
B=[i[0]+'&'+i[1] for i in bigrm]
a=''
for i in B:
    a+=' '+i+' '
    



wordcld=WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stop_words,
                min_font_size = 10).generate(a)
plt.figure( figsize = (8, 8),facecolor = None)
plt.imshow(wordcld)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()


wordcld1=WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stop_words,
                min_font_size = 10).generate(blockchain_texts)
plt.figure( figsize = (8, 8),facecolor = None)
plt.imshow(wordcld1)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

a
# Out:
# ' reserve&bank  bank&forming  forming&expert  expert&committee  committee&based  based&institute  institute&development  development&research  research&banking  banking&technology  technology&study  study&approach  approach&distributed  distributed&ledger  ledger&technology  technology&help  help&support  support&shiftdirector  shiftdirector&could  could&play  play&role  role&financial  financial&systempreliminary  systempreliminary&discuss  discuss&secure  secure&transaction  transaction&study  study&research  research&paymentsecurity  paymentsecurity&indeed  indeed&prove  prove&essential  essential&transforming  transforming&financial  financial&system  system&part  part&effort  effort&move  move&away  away&heavy  heavy&reliance  reliance&cash  cash&basedbank  basedbank&settlement  settlement&normally  normally&take  take&three  three&days  days&based  based&payment  payment&verification  verification&technology  technology&take  take&less  less&tier  tier&securityagarwal  securityagarwal&head  head&bankseveral  bankseveral&data  data&security  security&regulatory  regulatory&oversight  oversight&would  would&need  need&widely  widely&financial  financial&systemrelevance  systemrelevance&transaction  transaction&register  register&available  available&publicly  publicly&sequential  sequential&record  record&serve  serve&effective  effective&tool  tool&transaction  transaction&settlement  settlement&among  among&different  different&payment  payment&chain  chain&chief  chief&risk  risk&officer  officer&global  global&businesstechnology  businesstechnology&need  need&transaction  transaction&intermediary  intermediary&clearinghouse  clearinghouse&financial  financial&establishment  establishment&thus  thus&quick  quick&secure  secure&inexpensiveseven  inexpensiveseven&bank  bank&morgan  morgan&chase  chase&already  already&support  support&certain  certain&cross  cross&border  border&fortunemeanwhile  fortunemeanwhile&bank  bank&digital  digital&division  division&harness  harness&technology  technology&according  according&newsbank  newsbank&reportedly  reportedly&create  create&position  position&chief  chief&technology  technology&digital  digital&officerofficer  officerofficer&report  report&directly  directly&charge  charge&newly  newly&team  team&technology  technology&digital  digital&group  group&work  work&solely  solely&improving  improving&bank  bank&digital  digital&reach  reach&technology  technology&said  said&recent  recent&interview  interview&mintagarwal  mintagarwal&technology  technology&assist  assist&banking  banking&providing  providing&lower  lower&cost  cost&platform  platform&transaction  transaction&securityexample  securityexample&bank  bank&create  create&link  link&point  point&made  made&received  received&point  point&confirmation  confirmation&another  another&group  group&providekhan  providekhan&deputy  deputy&governor  governor&said  said&recent  recent&presentation  presentation&technology  technology&significant  significant&role  role&play  play&financial  financial&systemkhan  systemkhan&lack  lack&card  card&rather  rather&cashimplement  cashimplement&customer  customer&liability  liability&framework  framework&ease  ease&cashwould  cashwould&define  define&liability  liability&well  well&banker  banker&debit  debit&credit  credit&encourage  encourage&make  make&card  card&based  based&khanbased  khanbased&open  open&security  security&alliance  alliance&founder  founder&watch  watch&sure  sure&risk  risk&fraud  fraud&substantially  substantially&technology  technology&transparencyhowever  transparencyhowever&question  question&whether  whether&technology  technology&ready  ready&widespread  widespread&adoption  adoption&whether  whether&truly  truly&upsides  upsides&cannot  cannot&conventionalremains  conventionalremains&unclear  unclear&financial  financial&industry  industry&would  would&shift  shift&present  present&regulatory  regulatory&regime  regime&quasi  quasi&autonomous  auton ...
